# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
times = pd.read_csv('data/Biase_Times.csv')
times.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>curve1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Zygote_1</td>
#       <td>0.473029</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Zygote_2</td>
#       <td>1.011498</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Zygote_3</td>
#       <td>6.928720</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Zygote_4</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Zygote_5</td>
#       <td>0.000000</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
plt.figure()
plt.plot(times['curve1'])
plt.show()

# %%
plt.figure()
plt.hist(times['curve1'])
plt.show()

# %%
times2 = pd.read_csv('data/Borensztein_Times.csv')
times2.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>curve1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Oo_B6_4</td>
#       <td>12.439635</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Oo_B6_18</td>
#       <td>12.685788</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Oo_B6_20</td>
#       <td>2.589074</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Oo_B6_21</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Oo_Cast_10</td>
#       <td>0.000000</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
plt.figure()
plt.plot(times2['curve1'])
plt.show()

# %%
plt.figure()
plt.hist(times2['curve1'])
plt.show()

# %%
counts = pd.read_csv('data/Counts.txt', delim_whitespace=True)
counts
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>16cell_1.10</th>
#       <th>16cell_1.11</th>
#       <th>16cell_1.12</th>
#       <th>16cell_1.13</th>
#       <th>16cell_1.14</th>
#       <th>16cell_1.15</th>
#       <th>16cell_1.2</th>
#       <th>16cell_1.3</th>
#       <th>16cell_1.4</th>
#       <th>16cell_1.5</th>
#       <th>...</th>
#       <th>64C_CB_54</th>
#       <th>64C_CB_56</th>
#       <th>64C_BC_9</th>
#       <th>64C_BC_11</th>
#       <th>64C_BC_21</th>
#       <th>64C_BC_23</th>
#       <th>64C_BC_24</th>
#       <th>64C_BC_26</th>
#       <th>64C_CB_58</th>
#       <th>64C_CB_60</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...
